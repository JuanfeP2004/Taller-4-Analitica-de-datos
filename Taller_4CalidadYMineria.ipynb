# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanfeP2004/Taller-4-Analitica-de-datos/blob/main/Taller_4CalidadYMineria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Practica 4 de analitica de datos**
# ###Juan Felipe Ramírez Castañeda
# ###Aura Marcela Arbelaez

# %% [markdown]
# ##**1. Calidad de datos**
# ##**2. Modelos de datos**

# %%
#Importaciones
import pandas as pd # manipulacion dataframes
import numpy as np  # matrices y vectores
import matplotlib.pyplot as plt #gráfica

# %%
datos = pd.read_csv('datosSueno.csv', sep=",", na_filter=False)
datos.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200           None
# ...

# %% [markdown]
# #**1. Calidad de datos**
